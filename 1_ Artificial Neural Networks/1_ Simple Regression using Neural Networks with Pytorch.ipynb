# %% [markdown]
# ## Import Necessary Libraries

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')

# %%
data = pd.read_csv("Regression_Data.csv")

# %%
data
# Out:
#     Ind_Data  Dependent_Data
# 0        1.1           39343
# 1        1.3           46205
# 2        1.5           37731
# 3        2.0           43525
# 4        2.2           39891
# 5        2.9           56642
# 6        3.0           60150
# 7        3.2           54445
# 8        3.2           64445
# 9        3.7           57189
# 10       3.9           63218
# 11       4.0           55794
# 12       4.0           56957
# 13       4.1           57081
# 14       4.5           61111
# 15       4.9           67938
# 16       5.1           66029
# 17       5.3           83088
# 18       5.9           81363
# 19       6.0           93940
# 20       6.8           91738
# 21       7.1           98273
# 22       7.9          101302
# 23       8.2          113812
# 24       8.7          109431
# 25       9.0          105582
# 26       9.5          116969
# 27       9.6          112635
# 28      10.3          122391
# 29      10.5          121872

# %%
X = data['Ind_Data'].values.reshape(-1,1)
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y = data['Dependent_Data'].values.reshape(-1,1)
y
# Out:
# array([[ 39343],
#        [ 46205],
#        [ 37731],
#        [ 43525],
#        [ 39891],
#        [ 56642],
#        [ 60150],
#        [ 54445],
#        [ 64445],
#        [ 57189],
#        [ 63218],
#        [ 55794],
#        [ 56957],
#        [ 57081],
#        [ 61111],
#        [ 67938],
#        [ 66029],
#        [ 83088],
#        [ 81363],
#        [ 93940],
#        [ 91738],
#        [ 98273],
#        [101302],
#        [113812],
#        [109431],
#        [105582],
#        [116969],
#        [112635],
#        [122391],
#        [121872]], dtype=int64)

# %% [markdown]
# ## Visualize the data

# %%
 ## plt.figure(figsize =(12,6))
plt.scatter(X, y,color = 'b')
plt.ylabel('y', fontsize = 15)
plt.xlabel('X', fontsize = 15);

# %% [markdown]
# # Transforming to torch tensors

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)

# %%
X
# Out:
# tensor([[ 1.1000],
#         [ 1.3000],
#         [ 1.5000],
#         [ 2.0000],
#         [ 2.2000],
#         [ 2.9000],
#         [ 3.0000],
#         [ 3.2000],
#         [ 3.2000],
#         [ 3.7000],
#         [ 3.9000],
#         [ 4.0000],
#         [ 4.0000],
#         [ 4.1000],
#         [ 4.5000],
#         [ 4.9000],
#         [ 5.1000],
#         [ 5.3000],
#         [ 5.9000],
#         [ 6.0000],
#         [ 6.8000],
#         [ 7.1000],
#         [ 7.9000],
#         [ 8.2000],
#         [ 8.7000],
#         [ 9.0000],
#         [ 9.5000],
#         [ 9.6000],
#         [10.3000],
#         [10.5000]])

# %% [markdown]
# ## Create Neural Network Model

# %%
model = nn.Sequential(nn.Linear(1,1),)

model
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=1, bias=True)
# )

# %% [markdown]
# # Setting the Parameters

# %%
learningRate = 0.001
lossfunc = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(),lr = learningRate)   # SGD = Stochastic Gradient Descent

# %% [markdown]
# # Training the Neural Network

# %%
epochs = 5001  # Number of times we pass the data to the neural network.
losses = torch.zeros(epochs)

for epoch in range(epochs):
    ypred = model(X)
    loss = lossfunc(ypred,y)
    losses[epoch] = loss

    # Back Propagation

    optimizer.zero_grad()     # Initializing the gradient to zero. zero_grad() restarts looping without losses from the last
                              # step if you use the gradient method for decreasing the error (or losses).If you do not use
                              #zero_grad() the loss will increase not decrease as required. Gradients accumulate with every backprop.

    loss.backward()           # Calculate Gradient of all parameters.

    optimizer.step()          # This is used to update the parameters so that error could be reduced.

    if (epoch % 100) == 0:
     print(f'epochs : {epoch} loss : {loss.detach(): 1.2f}')
# Out:
# epochs : 0 loss :  6502401024.00
# epochs : 100 loss :  144398272.00
# epochs : 200 loss :  135217168.00
# epochs : 300 loss :  126782408.00
# epochs : 400 loss :  119032080.00
# epochs : 500 loss :  111910672.00
# epochs : 600 loss :  105367168.00
# epochs : 700 loss :  99354584.00
# epochs : 800 loss :  93829904.00
# epochs : 900 loss :  88753544.00
# epochs : 1000 loss :  84089104.00
# epochs : 1100 loss :  79803144.00
# epochs : 1200 loss :  75864976.00
# epochs : 1300 loss :  72246392.00
# epochs : 1400 loss :  68921432.00
# epochs : 1500 loss :  65866284.00
# epochs : 1600 loss :  63059020.00
# epochs : 1700 loss :  60479568.00
# epochs : 1800 loss :  58109436.00
# epochs : 1900 loss :  55931580.00
# epochs : 2000 loss :  53930492.00
# epochs : 2100 loss :  52091772.00
# epochs : 2200 loss :  50402264.00
# epochs : 2300 loss :  48849840.00
# epochs : 2400 loss :  47423412.00
# epochs : 2500 loss :  46112728.00
# epochs : 2600 loss :  44908364.00
# epochs : 2700 loss :  43801756.00
# epochs : 2800 loss :  42784948.00
# epochs : 2900 loss :  41850660.00
# epochs : 3000 loss :  40992168.00
# epochs : 3100 loss :  40203336.00
# epochs : 3200 loss :  39478516.00
# epochs : 3300 loss :  38812524.00
# epochs : 3400 loss :  38200564.00
# epochs : 3500 loss :  37638252.00
# epochs : 3600 loss :  37121552.00
# epochs : 3700 loss :  36646800.00
# epochs : 3800 loss :  36210596.00
# epochs : 3900 loss :  35809748.00
# epochs : 4000 loss :  35441456.00
# epochs : 4100 loss :  35103048.00
# epochs : 4200 loss :  34792076.00
# epochs : 4300 loss :  34506376.00
# epochs : 4400 loss :  34243828.00
# epochs : 4500 loss :  34002600.00
# epochs : 4600 loss :  33780944.00
# epochs : 4700 loss :  33577272.00
# epochs : 4800 loss :  33390134.00
# epochs : 4900 loss :  33218168.00
# epochs : 5000 loss :  33060170.00

# %%
ypred
# Out:
# tensor([[ 33779.8906],
#         [ 35755.2656],
#         [ 37730.6406],
#         [ 42669.0781],
#         [ 44644.4570],
#         [ 51558.2734],
#         [ 52545.9609],
#         [ 54521.3359],
#         [ 54521.3359],
#         [ 59459.7773],
#         [ 61435.1523],
#         [ 62422.8398],
#         [ 62422.8398],
#         [ 63410.5273],
#         [ 67361.2812],
#         [ 71312.0312],
#         [ 73287.4062],
#         [ 75262.7812],
#         [ 81188.9141],
#         [ 82176.6016],
#         [ 90078.1016],
#         [ 93041.1641],
#         [100942.6719],
#         [103905.7344],
#         [108844.1719],
#         [111807.2422],
#         [116745.6797],
#         [117733.3672],
#         [124647.1875],
#         [126622.5625]], grad_fn=<AddmmBackward0>)

# %%
ypred.detach()
# Out:
# tensor([[ 33779.8906],
#         [ 35755.2656],
#         [ 37730.6406],
#         [ 42669.0781],
#         [ 44644.4570],
#         [ 51558.2734],
#         [ 52545.9609],
#         [ 54521.3359],
#         [ 54521.3359],
#         [ 59459.7773],
#         [ 61435.1523],
#         [ 62422.8398],
#         [ 62422.8398],
#         [ 63410.5273],
#         [ 67361.2812],
#         [ 71312.0312],
#         [ 73287.4062],
#         [ 75262.7812],
#         [ 81188.9141],
#         [ 82176.6016],
#         [ 90078.1016],
#         [ 93041.1641],
#         [100942.6719],
#         [103905.7344],
#         [108844.1719],
#         [111807.2422],
#         [116745.6797],
#         [117733.3672],
#         [124647.1875],
#         [126622.5625]])

# %% [markdown]
# # Plotting Loss Vs Epochs

# %%
plt.figure(figsize =(12,6))
plt.plot(np.arange(epochs), losses.detach(), 'm', lw = 3)
plt.xlabel('Epochs', fontsize = 15)
plt.ylabel( 'Loss', fontsize = 15)
plt.show()

# %% [markdown]
# # Weight and Bias of the Trained Model

# %%
print(model[0].weight.detach().numpy())
print(model[0].bias.detach().numpy())
# Out:
# [[9876.699]]
# [22916.537]

# %% [markdown]
# # Creating a test data

# %%
test_data = np.linspace(0,11,30).reshape(-1,1)

# %%
X_test = torch.tensor(test_data, dtype = torch.float32)

# %%
yt = model(X_test)

# %%
plt.figure(figsize =(12,6))
plt.plot(X, y,'bs',label = 'RealData')
plt.plot(X_test, yt.detach(),'r', label = 'Predicted Data')
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# # Check the Performance of the Model

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(y, yt.detach())))
print('MAE:', np.sqrt(metrics.mean_absolute_error(y, yt.detach())))
print('R2:', metrics.r2_score(y, yt.detach()))
# Out:
# RMSE: 9997.5625
# MAE: 92.345085
# R2: 0.8624206980687665
